# %%
import matplotlib.pyplot as plt
import pandas as pd

# Data extracted from the user's provided logs
data = {
    'CNN': {
        "loss": [1.6600, 1.3109, 1.1571, 1.0698, 1.0120, 0.9697, 0.9345, 0.9103, 0.8903, 0.8706,
             0.8542, 0.8330, 0.8245, 0.8065, 0.7985, 0.7890, 0.7770, 0.7718, 0.7569, 0.7432],
    "accuracy": [39.00, 52.83, 58.94, 62.23, 64.35, 66.07, 67.24, 67.95, 68.74, 69.45,
                           70.27, 70.83, 71.40, 71.92, 72.39, 72.48, 72.96, 73.25, 73.72, 74.28]
    },
    'ResNet-18': {
        'accuracy': [41.89, 59.83, 68.89, 74.25, 78.03, 80.40, 82.42, 83.85, 84.97, 86.00, 87.16, 87.95, 88.78, 89.11, 90.01, 93.21, 94.06, 94.29, 94.52, 94.73],
        'loss': [1.5690, 1.1133, 0.8755, 0.7295, 0.6315, 0.5598, 0.5104, 0.4638, 0.4306, 0.3996, 0.3694, 0.3476, 0.3225, 0.3086, 0.2887, 0.2001, 0.1798, 0.1697, 0.1609, 0.1567]
    },
    'EfficientNet-B0': {
        'train_accuracy': [59.18, 73.98, 78.08, 80.66, 82.24, 83.31, 84.48, 85.36, 86.20, 86.69, 87.61, 88.05, 88.45, 88.91, 89.71, 89.71, 90.39, 90.74, 91.11, 91.41],
        'train_loss': [1.1732, 0.7584, 0.6375, 0.5616, 0.5176, 0.4811, 0.4485, 0.4223, 0.4025, 0.3856, 0.3582, 0.3431, 0.3362, 0.3217, 0.2989, 0.2981, 0.2773, 0.2678, 0.2555, 0.2425]
    }
}

epochs = range(1, 21)

# Plotting Accuracy
plt.figure(figsize=(12, 6))
plt.plot(epochs, data['CNN']['accuracy'], 'o-', label='CNN (Training)')
plt.plot(epochs, data['ResNet-18']['accuracy'], 's-', label='ResNet-18 (Training)')
plt.plot(epochs, data['EfficientNet-B0']['train_accuracy'], '^-', label='EfficientNet-B0 (Training)')
plt.title('Model Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.xticks([1, 5, 10, 15, 20])
plt.legend()
plt.grid(True)
plt.show()

# Plotting Loss
plt.figure(figsize=(12, 6))
plt.plot(epochs, data['CNN']['loss'], 'o-', label='CNN (Training)')
plt.plot(epochs, data['ResNet-18']['loss'], 's-', label='ResNet-18 (Training)')
plt.plot(epochs, data['EfficientNet-B0']['train_loss'], '^-', label='EfficientNet-B0 (Training)')
plt.title('Model Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.xticks([1, 5, 10, 15, 20])
plt.legend()
plt.grid(True)
plt.show()
